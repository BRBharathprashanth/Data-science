# %%
# Question: Count vowels in the string "Hello World"
text = "Hello World"
vowels = "aeiouAEIOU"
count = sum(1 for char in text if char in vowels)
print(f"String: {text}")
print(f"Number of vowels: {count}")
# Out:
# String: Hello World
# Number of vowels: 3

# %%
# Question 1: Reverse the string "Python Programming"
string="python programming"
rev=string[::-1]
print(rev)
# Out:
# gnimmargorp nohtyp

# %%
# Question 2: Check if "racecar" is a palindrome
str="racecar"
if str==str[::-1]:
  print("palindrome")
else:
  print("not plaindrome")
# Out:
# palindrome

# %%
# Question 3: Count the number of words in "Python is a great programming language"
words="Python is a great programming language"
words=words.split()
count=len(words)
print("number of words",count)
# Out:
# number of words 6

# %%
# Question 4: Convert "hello world" to title case
words="hello world"
words=words.title()    ##we cannot use upper case here(upper = all letters)
print(words)
# Out:
# Hello World

# %%
# Question 5: Find the length of string "Data Science"
str="data science"
word=len(str)
print(word)
# Out:
# 12

# %%
# Question 6: Replace all spaces with underscores in "Machine Learning"
str="machine learning"
a=str.replace(" ",'_')
print(a)
# Out:
# machine_learning

# %%
# Question 7: Check if "python" is in "Python Programming Language"
str="Python Programming Language"
if "Python" in str:
  print("Python is found")
else:
  print("Python is not found")
# Out:
# Python is found

# %%
##print("\nQuestion 8: Extract the first 5 characters from 'Artificial Intelligence'")
text = "Artificial Intelligence"
first_5_chars = text[:5]
print(f"The first 5 characters are: {first_five_chars}")
# Out:
# The first 5 characters are: Artif

# %%
# Question 9: Convert "UPPERCASE" to lowercase
str="HELLO DATASCIENCE"
a=str.lower()
print(a)
# Out:
# hello datascience

# %%
# Question 10: Remove all vowels from "Computer Science"
word = "Computer Science"
result = ""
for i in word:
    if i.lower() not in "aeiou":
        result += i
print(result)
# Out:
# Cmptr Scnc

# %%
# Question 12: Check if two strings are anagrams: "listen" and "silent"
str1 = "listen"
str2 = "silent"

if sorted(str1) == sorted(str2):
    print(f"'{str1}' and '{str2}' are anagrams.")
else:
    print(f"'{str1}' and '{str2}' are not anagrams.")
# Out:
# 'listen' and 'silent' are anagrams.

# %%
# Question 13: Capitalize first letter of each word in "python programming language"
text = "python programming language"
capitalized_text = text.title()
print(capitalized_text)
# Out:
# Python Programming Language

# %%
# Question 14: Count consonants in "Hello World"
text = "Hello World"
vowels = "aeiouAEIOU"
consonant_count = 0
for char in text:
    if char.isalpha() and char not in vowels:
        consonant_count += 1
print(f"Number of consonants: {consonant_count}")
# Out:
# Number of consonants: 7

# %%
# Question 15: Find the longest word in "Python is a programming language"
##print("\nQuestion 15: Find the longest word in 'Python is a programming language'")
text = "Python is a programming language"
words = text.split()
longest_word = max(words, key = len)
print(longest_word)
# Out:
# programming

# %%
# Question 16: Remove all punctuation from "Hello, World! How are you?"
text = "Hello, World! How are you?"
cleaned_text = text.translate(str.maketrans('', '', string.punctuation))
print(cleaned_text)
# Out:
# Hello World How are you

# %%
# Question 49: Convert "hello world" to ROT13 encoding
import codecs

text = "hello world"
rot13_text = codecs.encode(text, 'rot_13')

print(rot13_text)
# Out:
# uryyb jbeyq

# %%
# Question 17: Check if a string starts with 'python'
text = "python "
if text.startswith("python"):
    print(f"The string '{text}' starts with 'python'.")
else:
    print(f"The string '{text}' does not start with 'python'.")
# Out:
# The string 'python ' starts with 'python'.

# %%
# Question 18: Find the index of first occurrence of 'o' in "Hello World"
text = "hello world"
index = text.find('o')
print(index)
# Out:
# 4

# %%
# Question 48: Find all substrings of "abc"
text = "abc"
for i in range(len(text)):
    for j in range(i + 1, len(text) + 1):
        print(text[i:j])
# Out:
# a
# ab
# abc
# b
# bc
# c
