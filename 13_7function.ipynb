# %%
##before fuction runs
##hello student
##after function runs
def decorater(func):
    def wrapper(*args,**kwargs):
        print("before fuction runs")
        result=func(*args,**kwargs)
        print("after function runs")
        return result
    return wrapper

@decorater
def say_hello():
    print("hello student")
say_hello()
# Out:
# before fuction runs
# hello student
# after function runs
